# %% [markdown]
# # RMCT benchmarking
#
# This notebook summarises public benchmark outputs for population coverage, capability specificity and supplier-search noise reduction.

# %%
from pathlib import Path
import pandas as pd

DATA = Path('../data')
bench = pd.read_csv(DATA / 'benchmark_results_aggregate.csv')
briefs = pd.read_csv(DATA / 'benchmark_briefs.csv')

print('Benchmark rows:', len(bench))
print('Brief criterion rows:', len(briefs))
display(bench.head())
display(briefs.head())

# %% [markdown]
# ## 1. Population coverage
#
# Population coverage evaluates whether a system can reach the regional supplier population using public data.

# %%
display(bench[bench['metric_group'].str.contains('Population', case=False, na=False)])

# %% [markdown]
# ## 2. Capability specificity
#
# Capability specificity evaluates whether a system provides actionable capability descriptors per covered firm.

# %%
display(bench[bench['metric_group'].str.contains('Specificity', case=False, na=False)])

# %% [markdown]
# ## 3. Search noise reduction
#
# Search noise reduction evaluates whether RMCT reduces the candidate supplier pool for multi-dimensional procurement briefs.

# %%
display(bench[bench['metric_group'].str.contains('Search', case=False, na=False)])

# %% [markdown]
# ## 4. Re-running retrieval benchmarks
#
# If query-level candidate counts are available, use:
#
# ```bash
# python code/05_benchmark_retrieval.py
# ```
